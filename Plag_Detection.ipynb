# %%
pip install sentence_transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 85 kB 4.3 MB/s
# ...
#      |████████████████████████████████| 5.8 MB 50.0 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 47.3 MB/s
# ...
#      |████████████████████████████████| 182 kB 64.8 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 51.4 MB/s
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=5b8ab7e9df13892415ccfad932b914d025241511bf6248a922ec808f028990a1
#   Stored in directory: /root/.cache/pip/wheels/5e/6f/8c/d88aec621f3f542d26fac0342bef5e693335d125f4e54aeffe
# Successfully built sentence-transformers
# ...

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('bert-base-nli-mean-tokens')
# Out:
# Downloading:   0%|          | 0.00/391 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.95k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/625 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/399 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/drive/MyDrive/English---Hornbill---Class-11.csv')

# %%
def Clean(text):
    
    text = re.sub(r'https?:\/\/.*[\r\n]*', '', text)
    text = re.sub(r'http?:\/\/.*[\r\n]*', '', text) #remove URL
    
    text=text.replace(r'&amp;?',r'and')
    text=text.replace(r'&lt;',r'<')
    text=text.replace(r'&gt;',r'>') #remove special character 
    text=re.sub(r'[0-9]','',text)
    
    text = re.sub(r"(?:\@)\w+", '', text)
    text=text.encode("ascii",errors="ignore").decode()
    text=re.sub(r'[:"#$%&\*+,-/:;<=>@\\^_`{|}~]+','',text)
    
    text=re.sub(r'[!]+','!',text)
    text=re.sub(r'[?]+','?',text)
    text=re.sub(r'[.]+','.',text)
   
    text=re.sub(r"'","",text)
    text=re.sub(r"\(","",text)
    text=re.sub(r"\)","",text)
    
    text=" ".join(text.split())
    return text

# %%
import re

# %%
df['Text']=df['Text'].apply(lambda x: Clean(x))

# %%
df1=pd.DataFrame()

# %%
Enter=input("enter the text")
# Out:
# enter the textThe cardboard shows me how it was When the two girl cousins went paddling, Each one holding one of my mother’s hands, And she the big girl — some twelve years or so. All three stood still to smile through their hair At the uncle with the camera. A sweet face, My mother’s, that was before I was born. And the sea, which appears to have changed less, Washed their terribly transient feet.

# %%
df1['Text']=[Enter]

# %%
df1.head()
# Out:
#                                 Text
# 0  The cardboard shows me how it was

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-772380087a52> in <module>
# ----> 1 df.Text.type()
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'type'

# %%
# Out:
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-35-d191f91df9bf>", line 1, in <module>
#     input=eval(input)
#
#   File "<string>", line 1
#     my name is avishi
#        ^
# SyntaxError: invalid syntax

# %%
df1['Text']=df1['Text'].apply(lambda x: Clean(x))

# %%
df.head()
# Out:
#    Unnamed: 0                                       Text  page no.  \
# 0           0  First Edition February Phalguna Reprinted         1
# 1           0                    Kartika October Kartika         1
# 2           0                        Pausa January Magha         1
# 3           0                    Pausa February Phalguna         1
# 4           0                   Kartika November Kartika         1
#
#                        Book Name
# 0  English---Hornbill---Class-11
# 1  English---Hornbill---Class-11
# 2  English---Hornbill---Class-11
# 3  English---Hornbill---Class-11
# 4  English---Hornbill---Class-11

# %%
df.shape
# Out:
# (3951, 4)

# %%
sentence_embeddings = model.encode(df['Text'])

# %%
sentences_embedding_results=model.encode(df1['Text'])

# %%
sentence_embeddings.shape
# Out:
# (3951, 768)

# %%
df1.head()
# Out:
#                                                 Text
# 0  The cardboard shows me how it was When the two...

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
sentences_embedding_results[0].shape
# Out:
# (768,)

# %%
Level_of_similarity=cosine_similarity(
    [sentences_embedding_results[0]],
    sentence_embeddings[0:]
)

# %%
Level_of_similarity.shape
# Out:
# (1, 3951)

# %%
for i in Level_of_similarity:
  sum=0
  count=0
  for j in i:
    if(j>0.50):
      sum+=j
      count+=1
      print(j)
  print(sum/count)
# Out:
# 0.54183996
# 0.56053466
# 0.51205325
# 0.5093899
# 0.5696608
# 0.556943
# 0.53827745
# 0.5989824
# 0.5354753
# 0.55185354
# 0.5475010216236115

# %%
from sklearn.pipeline import Pipeline
text_clf = Pipeline([('clean', Clean()),
                     ('tfidf', TfidfTransformer()),
                      ('clf', MultinomialNB())])
text_clf
